# %%
#de momento importamos las librerías que seguro o casi seguro tenemos que usar

import pandas as pd 
import numpy as np
import regex as re

# %%
#igualmente importamos los datos, como tiene caracteres especiales hay que añadir como argumento encoding="latin1"

tiburones = pd.read_csv(r"C:\Users\Juan\Desktop\IronHack_apuntes\Proyecto_Pandas_Tiburones\attacks.csv", encoding= "utf-8", encoding_errors="ignore")

# %% [markdown]
# ### Exploración inicial

# %%
tiburones.shape
# Out:
# (25723, 24)

# %%
#vemos a ver qué hay en los 50 primeros

tiburones.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity            Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling     Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  AdysonMcNeely     F  ...
# 2                    Habush, Oahu      Surfing     John Denges    M  ...
# 3              Arrawarra Headland      Surfing            male    M  ...
# 4                        La Ticla  Free diving  Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
#qué cosa más rara, hay muchísimos nulos por detrás, hay que ver cuántos son


tiburones.tail()
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25718         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25719         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25720         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25721         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 25718  ...      NaN                    NaN  NaN          NaN  NaN
# 25719  ...      NaN                    NaN  NaN          NaN  NaN
# 25720  ...      NaN                    NaN  NaN          NaN  NaN
# 25721  ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# 25718           NaN           NaN            NaN         NaN         NaN
# 25719           NaN           NaN            NaN         NaN         NaN
# 25720           NaN           NaN            NaN         NaN         NaN
# 25721           NaN           NaN            NaN         NaN         NaN
# 25722           NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 24 columns]

# %%
tiburones.info(memory_usage= "deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 22.7 MB

# %%
#Nos quitamos las filas que sólo tienen caracteres nulos, nos hemos quitado unas 16000 filas

tiburones.dropna(how="all", inplace=True)
tiburones.shape
# Out:
# (8703, 24)

# %%
#sigue habiendo muchisimos que sobran por todos lados


tiburones.tail(20)
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 8683            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8684            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8685            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8686            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8687            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8688            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8689            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8690            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8691            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8692            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8693            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8694            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8695            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8696            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8697            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8698            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8699            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8700            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 8701            0  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25722          xx  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species  Investigator or Source  pdf href formula href  \
# 8683   ...      NaN                    NaN  NaN          NaN  NaN
# 8684   ...      NaN                    NaN  NaN          NaN  NaN
# 8685   ...      NaN                    NaN  NaN          NaN  NaN
# 8686   ...      NaN                    NaN  NaN          NaN  NaN
# 8687   ...      NaN                    NaN  NaN          NaN  NaN
# 8688   ...      NaN                    NaN  NaN          NaN  NaN
# 8689   ...      NaN                    NaN  NaN          NaN  NaN
# 8690   ...      NaN                    NaN  NaN          NaN  NaN
# 8691   ...      NaN                    NaN  NaN          NaN  NaN
# 8692   ...      NaN                    NaN  NaN          NaN  NaN
# 8693   ...      NaN                    NaN  NaN          NaN  NaN
# 8694   ...      NaN                    NaN  NaN          NaN  NaN
# 8695   ...      NaN                    NaN  NaN          NaN  NaN
# 8696   ...      NaN                    NaN  NaN          NaN  NaN
# 8697   ...      NaN                    NaN  NaN          NaN  NaN
# 8698   ...      NaN                    NaN  NaN          NaN  NaN
# 8699   ...      NaN                    NaN  NaN          NaN  NaN
# 8700   ...      NaN                    NaN  NaN          NaN  NaN
# 8701   ...      NaN                    NaN  NaN          NaN  NaN
# 25722  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case Number.1 Case Number.2 original order Unnamed: 22 Unnamed: 23
# 8683            NaN           NaN            NaN         NaN         NaN
# 8684            NaN           NaN            NaN         NaN         NaN
# 8685            NaN           NaN            NaN         NaN         NaN
# 8686            NaN           NaN            NaN         NaN         NaN
# 8687            NaN           NaN            NaN         NaN         NaN
# 8688            NaN           NaN            NaN         NaN         NaN
# 8689            NaN           NaN            NaN         NaN         NaN
# 8690            NaN           NaN            NaN         NaN         NaN
# 8691            NaN           NaN            NaN         NaN         NaN
# 8692            NaN           NaN            NaN         NaN         NaN
# 8693            NaN           NaN            NaN         NaN         NaN
# 8694            NaN           NaN            NaN         NaN         NaN
# 8695            NaN           NaN            NaN         NaN         NaN
# 8696            NaN           NaN            NaN         NaN         NaN
# 8697            NaN           NaN            NaN         NaN         NaN
# 8698            NaN           NaN            NaN         NaN         NaN
# 8699            NaN           NaN            NaN         NaN         NaN
# 8700            NaN           NaN            NaN         NaN         NaN
# 8701            NaN           NaN            NaN         NaN         NaN
# 25722           NaN           NaN            NaN         NaN         NaN
#
# [20 rows x 24 columns]

# %%
#Mi teoria es que si hacemos una copia sin la columna del numero de caso(que tiene datos que no son nan pero son inutiles), 
#y hacemos lo que hemos hecho antes para quitar todas las columnas sólo con nulos sabremos qué dimensiones son valores útiles

tiburones_copia_sincaso = tiburones.drop(columns=["Case Number"]).copy()

# %%
tiburones_copia_sincaso.dropna(how="all", inplace=True)

# %%
tiburones_copia_sincaso.shape
#de las 25000 filas originales sólo nos valen 6309
# Out:
# (6309, 23)

# %%
tiburones_copia_sincaso.tail(10) 

#sigue habiendo alguna fila que sobra pero ya tenemos índices
# Out:
#            Date  Year        Type             Country              Area  \
# 6299  1900-1905   0.0  Unprovoked                 USA    North Carolina
# 6300  1883-1889   0.0  Unprovoked              PANAMA               NaN
# 6301  1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)  Eastern Province
# 6302        NaN   NaN         NaN                 NaN               NaN
# 6303        NaN   NaN         NaN                 NaN               NaN
# 6304        NaN   NaN         NaN                 NaN               NaN
# 6305        NaN   NaN         NaN                 NaN               NaN
# 6306        NaN   NaN         NaN                 NaN               NaN
# 6307        NaN   NaN         NaN                 NaN               NaN
# 6308        NaN   NaN         NaN                 NaN               NaN
#
#                                  Location  Activity                   Name  \
# 6299                       Ocracoke Inlet  Swimming  Coast Guard personnel
# 6300                   Panama Bay 8N, 79W       NaN        Jules Patterson
# 6301  Below the English fort, Trincomalee  Swimming                   male
# 6302                                  NaN       NaN                    NaN
# 6303                                  NaN       NaN                    NaN
# 6304                                  NaN       NaN                    NaN
# 6305                                  NaN       NaN                    NaN
# 6306                                  NaN       NaN                    NaN
# 6307                                  NaN       NaN                    NaN
# 6308                                  NaN       NaN                    NaN
#
#      Sex   Age  ... Species                 Investigator or Source  \
# 6299    M  NaN  ...      NaN  F. Schwartz, p.23; C. Creswell, GSAF
# 6300    M  NaN  ...      NaN                   The Sun, 10/20/1938
# 6301    M   15  ...      NaN                            S.W. Baker
# 6302  NaN  NaN  ...      NaN                                   NaN
# 6303  NaN  NaN  ...      NaN                                   NaN
# 6304  NaN  NaN  ...      NaN                                   NaN
# 6305  NaN  NaN  ...      NaN                                   NaN
# 6306  NaN  NaN  ...      NaN                                   NaN
# 6307  NaN  NaN  ...      NaN                                   NaN
# 6308  NaN  NaN  ...      NaN                                   NaN
#
#                                  pdf  \
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
# 6302                             NaN
# 6303                             NaN
# 6304                             NaN
# 6305                             NaN
# 6306                             NaN
# 6307                             NaN
# 6308                             NaN
#
#                                            href formula  \
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6302                                                NaN
# 6303                                                NaN
# 6304                                                NaN
# 6305                                                NaN
# 6306                                                NaN
# 6307                                                NaN
# 6308                                                NaN
#
#                                                    href Case Number.1  \
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
# 6302                                                NaN           NaN
# 6303                                                NaN           NaN
# 6304                                                NaN           NaN
# 6305                                                NaN           NaN
# 6306                                                NaN           NaN
# 6307                                                NaN           NaN
# 6308                                                NaN           NaN
#
#      Case Number.2 original order Unnamed: 22 Unnamed: 23
# 6299       ND.0003            4.0         NaN         NaN
# 6300       ND.0002            3.0         NaN         NaN
# 6301       ND.0001            2.0         NaN         NaN
# 6302           NaN         6304.0         NaN         NaN
# 6303           NaN         6305.0         NaN         NaN
# 6304           NaN         6306.0         NaN         NaN
# 6305           NaN         6307.0         NaN         NaN
# 6306           NaN         6308.0         NaN         NaN
# 6307           NaN         6309.0         NaN         NaN
# 6308           NaN         6310.0         NaN         NaN
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Homogeneización de las columnas y más exploración

# %%
#Pillamos lo que podemos usar del df y homogeneizar las columnas para trabajar mejor
tiburones = tiburones.iloc[0:6302]
tiburones.columns = [col.lower().strip() for col in tiburones.columns]
tiburones.columns = tiburones.columns.str.replace('\s+', ' ', regex=True)
tiburones.columns = [col.replace(" ", "_") for col in tiburones.columns]

# %%
tiburones.shape
# Out:
# (6302, 24)

# %%
paises = [i for i in tiburones["country"].unique()]
print(len(paises)) #son muchisimos paises
print(paises)
# Out:
# 213
# ['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA', 'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA', 'ECUADOR', 'MALAYSIA', 'LIBYA', nan, 'CUBA', 'MAURITIUS', 'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN', 'EGYPT', 'ST HELENA, British overseas territory', 'COMOROS', 'REUNION', 'FRENCH POLYNESIA', 'UNITED KINGDOM', 'UNITED ARAB EMIRATES', 'PHILIPPINES', 'INDONESIA', 'CHINA', 'COLUMBIA', 'CAPE VERDE', 'Fiji', 'DOMINICAN REPUBLIC', 'CAYMAN ISLANDS', 'ARUBA', 'MOZAMBIQUE', 'FIJI', 'PUERTO RICO', 'ITALY', 'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE', 'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL', 'DIEGO GARCIA', 'TAIWAN', 'JAMAICA', 'PALESTINIAN TERRITORIES', 'GUAM', 'SEYCHELLES', 'BELIZE', 'NIGERIA', 'TONGA', 'SCOTLAND', 'CANADA', 'CROATIA', 'SAUDI ARABIA', 'CHILE', 'ANTIGUA', 'KENYA', 'RUSSIA', 'TURKS & CAICOS', 'UNITED ARAB EMIRATES (UAE)', 'AZORES', 'SOUTH KOREA', 'MALTA', 'VIETNAM', 'MADAGASCAR', 'PANAMA', 'SOMALIA', 'NEVIS', 'BRITISH VIRGIN ISLANDS', 'NORWAY', 'SENEGAL', 'YEMEN', 'GULF OF ADEN', 'Sierra Leone', 'ST. MAARTIN', 'GRAND CAYMAN', 'Seychelles', 'LIBERIA', 'VANUATU', 'MEXICO ', 'HONDURAS', 'VENEZUELA', 'SRI LANKA', ' TONGA', 'URUGUAY', 'INDIA', 'MICRONESIA', 'CARIBBEAN SEA', 'OKINAWA', 'TANZANIA', 'MARSHALL ISLANDS', 'EGYPT / ISRAEL', 'NORTHERN ARABIAN SEA', 'HONG KONG', 'EL SALVADOR', 'ANGOLA', 'BERMUDA', 'MONTENEGRO', 'IRAN', 'TUNISIA', 'NAMIBIA', 'NORTH ATLANTIC OCEAN', 'PORTUGAL', 'SOUTH CHINA SEA', 'BANGLADESH', 'PALAU', 'WESTERN SAMOA', 'PACIFIC OCEAN ', 'BRITISH ISLES', 'GRENADA', 'IRAQ', 'TURKEY', 'SINGAPORE', 'NEW BRITAIN', 'SUDAN', 'JOHNSTON ISLAND', 'SOUTH PACIFIC OCEAN', 'NEW GUINEA', 'RED SEA', 'NORTH PACIFIC OCEAN', 'FEDERATED STATES OF MICRONESIA', 'MID ATLANTIC OCEAN', 'ADMIRALTY ISLANDS', 'BRITISH WEST INDIES', 'SOUTH ATLANTIC OCEAN', 'PERSIAN GULF', 'RED SEA / INDIAN OCEAN', 'PACIFIC OCEAN', 'NORTH SEA', 'NICARAGUA ', 'MALDIVE ISLANDS', 'AMERICAN SAMOA', 'ANDAMAN / NICOBAR ISLANDAS', 'GABON', 'MAYOTTE', 'NORTH ATLANTIC OCEAN ', 'THE BALKANS', 'SUDAN?', 'ARGENTINA', 'MARTINIQUE', 'INDIAN OCEAN', 'GUATEMALA', 'NETHERLANDS ANTILLES', 'NORTHERN MARIANA ISLANDS', 'IRAN / IRAQ', 'JAVA', 'SIERRA LEONE', ' PHILIPPINES', 'NICARAGUA', 'CENTRAL PACIFIC', 'SOLOMON ISLANDS / VANUATU', 'SOUTHWEST PACIFIC OCEAN', 'BAY OF BENGAL', 'MID-PACIFC OCEAN', 'SLOVENIA', 'CURACAO', 'ICELAND', 'ITALY / CROATIA', 'BARBADOS', 'MONACO', 'GUYANA', 'HAITI', 'SAN DOMINGO', 'IRELAND', 'KUWAIT', 'YEMEN ', 'REUNION ISLAND', 'FALKLAND ISLANDS', 'CRETE', 'CYPRUS', 'EGYPT ', 'WEST INDIES', 'BURMA', 'LEBANON', 'PARAGUAY', 'BRITISH NEW GUINEA', 'CEYLON', 'OCEAN', 'GEORGIA', 'SYRIA', 'TUVALU', 'INDIAN OCEAN?', 'GUINEA', 'ANDAMAN ISLANDS', 'EQUATORIAL GUINEA / CAMEROON', 'COOK ISLANDS', 'TOBAGO', 'PERU', 'AFRICA', 'ALGERIA', 'Coast of AFRICA', 'TASMAN SEA', 'GHANA', 'GREENLAND', 'MEDITERRANEAN SEA', 'SWEDEN', 'ROATAN', 'Between PORTUGAL & INDIA', 'DJIBOUTI', 'BAHREIN', 'KOREA', 'RED SEA?', 'ASIA?', 'CEYLON (SRI LANKA)']

# %% [markdown]
# ### Limpiando los investigadores

# %%
tiburones["investigator_or_source"].fillna("unknown")
# Out:
# 0                            R. Collier, GSAF
# 1              K.McMurray, TrackingSharks.com
# 2              K.McMurray, TrackingSharks.com
# 3                              B. Myatt, GSAF
# 4                                   A .Kipper
#                         ...
# 6297         H. Taunton; N. Bartlett,  p. 234
# 6298    H. Taunton; N. Bartlett,  pp. 233-234
# 6299     F. Schwartz, p.23; C. Creswell, GSAF
# 6300                      The Sun, 10/20/1938
# 6301                               S.W. Baker
# Name: investigator_or_source, Length: 6302, dtype: object

# %% [markdown]
# ### Limpiando la columna de especies

# %%
#Vamos a rellenar los nulos con "desconocido", también 

tiburones["species"] = tiburones["species"].astype(str)
#tiburones = tiburones.loc[~tiburones["species"].str.contains("involvement")] habíamos pensado en quitar estos casos pero era quitar demasiada info
tiburones["species"].replace({"N/A": "unknown", "": "unknown", "nan": "unknown"}, inplace=True)  
tiburones["species"].fillna("unknown", inplace= True)

# %%
#vamos a limpiar la columna con regex
limpieza = {r'\bwhite\s*shark\b': "white_shark",
r'\btiger\s*shark\b': "tiger_shark",
r'\bbull(?:\b|[_-]?shark)\b': "bull_shark",
r'\bshortfin\s*mako\s*shark\b':"mako_shark",
r'\bhammerhead\s*shark\b': "hammerhead_shark",
r'\bblacktip\s*shark\b': "blacktip_shark",
r'\bblue\s*shark\b': 'blue_shark',
r'\blemon\s*shark\b':'lemon_shark',
r'\bdusky\s*shark\b':'dusky_shark',
r'\bspinner\s*shark\b': 'spinner_shark',
r'\bbronze[\W_]*whaler\s*shark\b': 'bronze_whale_shark',
r'\breef\s*shark\b': 'reef_shark',
r'\bblue\s*shark\b': 'blue_shark',
r'\bgalapagos\s*shark\b': "galapagos_shark",
r'\boceanic\s+white[\W_]*tip\s*shark\b': "oceanic_white_tip_sharl"}



for i, e in tiburones["species"].iteritems():
    for pattern, species in limpieza.items():
        if re.search(pattern, e, re.IGNORECASE):
            tiburones.loc[i, "species"] = species
            break

# %%
tiburones
# Out:
#      case_number         date    year        type             country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                   Panama Bay 8N, 79W           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        name sex  ...      species  \
# 0               Julie Wolfe   F  ...  white_shark
# 1            AdysonMcNeely    F  ...      unknown
# 2               John Denges   M  ...      unknown
# 3                      male   M  ...    2 m shark
# 4            Gustavo Ramos    M  ...  tiger_shark
# ...                     ...  ..  ...          ...
# 6297                   male   M  ...      unknown
# 6298                  Ahmun   M  ...      unknown
# 6299  Coast Guard personnel   M  ...      unknown
# 6300        Jules Patterson   M  ...      unknown
# 6301                   male   M  ...      unknown
#
#                      investigator_or_source                             pdf  \
# 0                          R. Collier, GSAF            2018.06.25-Wolfe.pdf
# 1            K.McMurray, TrackingSharks.com          2018.06.18-McNeely.pdf
# 2            K.McMurray, TrackingSharks.com           2018.06.09-Denges.pdf
# 3                            B. Myatt, GSAF        2018.06.08-Arrawarra.pdf
# 4                                 A .Kipper            2018.06.04-Ramos.pdf
# ...                                     ...                             ...
# 6297       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 6298  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 6299   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 6300                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 6301                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href_formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href case_number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      case_number.2 original_order unnamed:_22 unnamed:_23
# 0       2018.06.25         6303.0         NaN         NaN
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 3       2018.06.08         6300.0         NaN         NaN
# 4       2018.06.04         6299.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6297       ND.0005            6.0         NaN         NaN
# 6298       ND.0004            5.0         NaN         NaN
# 6299       ND.0003            4.0         NaN         NaN
# 6300       ND.0002            3.0         NaN         NaN
# 6301       ND.0001            2.0         NaN         NaN
#
# [6302 rows x 24 columns]

# %%
e = [e for e in tiburones.species.unique()]
print(e)
print(len(e))
# Out:
# ['white_shark', 'unknown', '2 m shark', 'tiger_shark', 'lemon_shark', 'mako_shark', 'reef_shark', 'Invalid incident', 'Tawny nurse shark, 2m', 'Shark involvement not confirmed', 'Questionable', '3 m shark', "6' shark", 'Wobbegong shark', '3.5 m shark', '1.8 m shark', 'blacktip_shark', 'Possibly a wobbegong', 'Injury believed caused by an eel, not a shark', 'galapagos_sharl', '2m shark', 'small shark', 'Wobbegong shark?', 'Juvenile nurse shark', "Nurse shark. 5'", 'Some drowned but other may have been killed by blue sharks', 'Cookiecutter shark', 'Wobbegong shark, 1 m', 'spinner_shark', "8' shark", 'Death may have been due to drowning', "5' shark", "4' to 5' shark", 'Porbeagle, 1.5 m', "5' to 6' shark", 'Nurse shark', 'Shark involvement questionable', 'Oceanic whitetip shark, 1.8 to 2 m', "4' shark", 'A small shark', "Sandtiger shark  2'", 'blue_shark', '"A small shark"', 'Shark involvement prior to death not confirmed', 'No shark invovlement ', 'Seven-gill shark', '3m shark, probably a smooth hound', "3' shark", "9' shark", 'Shark involvement highly doubtful', 'No shark invovlement - it ws a publicity stunt', "10' shark", 'a small shark', 'Wobbegong shark, 2m', 'Broadnose sevengill shark, 1.5 m', " 6' to 8' shark", "3' to 4' shark", 'Invalid', "Nurse shark, 4'", 'Angel shark', 'dogfish shark', 'Tawny nurse shark', "3' to 5' shark", "Said to involve an 8' shark but more likely damage caused by debris", '3+ m shark', 'Mako shark', 'Bronze whaler sharks x 3', "Nurse shark, 2'", "Mako shark, 1.5 m [5'] ", 'Nurse shark, 2.5-ft', 'Bronze whaler', 'Sandtiger shark', 'No shark involvement', "Silky shark, 6.5'", 'bronze_whale_shark', 'Hammerhead sp.', 'juvenile shark', 'hammer_head_shark', "4' shark?", "Thought to involve a 3' to 4' shark, but shark involvement not confirmed", 'Mako shark, 100-lb', 'Shark involvement not cofirmed', "6' to 7' shark", 'small nurse shark', '1m to 1.2 m shark', '3- to 4-foot shark', '3.5 to 4 m shark', '2 m to  3 m shark', '5 m shark', '1.5 m shark', 'Raggedtooth shark, 1.3 m', 'Shark involvement prior to death still to be determined', 'Shark involvement not confirmed & highly unlikely', 'Goblin shark', "2' shark", "12' to 14' shark", '1 m shark', "8' to 10' shark", "7' shark", "4' to 6' shark", "4' tp 5' shark", '1.8 metre shark', "6' to 8' shark", "Oceanic whitetip shark'", " Sandbar shark, 3' to 4'", '3m shark', ' Tawney nurse shark, 1m', 'Cow shark', ' Raggedtooth shark, 2m', '7-gill shark?', '1m shark', '7-gill shark', 'Oceanic whitetip shark', ' Wobbegong shark, 1.6 to 1.8m ', 'Nurse shark?', 'Salmon shark', "Mako shark, 5'", 'Wobbegong, 2m', 'Grey nurse shark, 3m', 'shark involvement not confirmed', 'Raggedtooth shark, 1.5 m', '"small sharks"', '2.5 m shark', "2' to 3' shark", "3.5' to 4' shark", "Porbeagle shark, 7'", '4.5 m shark', 'Salmon shark suspected, but unlikely', "14' to 18'shark", "15' shark", '18" to 24" shark', 'Tawny nurse shark, 40cm', 'Grey nurse shark', "7' to 8' shark ", 'Raggedtooth shark', 'Port Jackson shark, 1m', "10' to 12' shark", '2 to 2.5 m shark', "Possibly a 5' to 6' sandtiger shark", '4 m shark', "Oceanic whitetip shark, 7'", "Sevengill shark, 6' to 8'", 'Zambesi shark', "Sandbar shark, 8'", "1' to 2' shark", '3 m to 4 m shark', 'Oceanic whitetip shark, 2.5m ', 'Mako shark ', 'Oceanic whitetip shark, 2.5m, female', "Porbeagle shark, 8' ", 'Shark involvement prior to death was not confirmed', "Sandtiger shark, 4' to 5'", 'Nurse shark, juvenile ', '20 to 30kg shark', "14' shark", "Oceanic whitetip shark, 6'", 'Wobbegong shark, 1.6m', '2 m to 3 m shark', 'Zambesi shark, 2m ', "Sandtiger shark, 8'", 'Thresher shark', 'Spurdog', "Nurse shark, 6'", 'Thought to involve a Bronze whale shark, 2m', 'Shark involvement probable, but not confirmed', 'Oceanic whitetip shark, 2.5 to 3m', '80 kg shark', "5' to 8' shark", 'Thought to involve a cookie cutter shark', 'Wobbegong shark, 60cm', '2.6 m shark', 'dusky_shark', 'Mako shark, 3m', 'Broadnose sevengill shark', 'Raggedtooth shark, 2m ...
# 767

# %% [markdown]
# ### Limpiando un poco el sexo

# %%
#vamos a solucionar el sexo que eso va a ser más sencillo
tiburones["sex"].unique()
tiburones["sex"].fillna('unknown', inplace=True)

tiburones["sex"].replace({'M ': 'M',
                'lli': 'unknown', 
                'N': 'unknown',
                '.': 'unknown'
                }, inplace=True)  #vamos a homogeneizar las "M" y vamos a rellenar los datos mal introducidos y los NaN

tiburones
# Out:
#      case_number         date    year        type             country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                   Panama Bay 8N, 79W           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        name sex  ...          species  \
# 0               Julie Wolfe   F  ...      White shark
# 1            AdysonMcNeely    F  ...          unknown
# 2               John Denges   M  ...          unknown
# 3                      male   M  ...        2 m shark
# 4            Gustavo Ramos    M  ...  Tiger shark, 3m
# ...                     ...  ..  ...              ...
# 6297                   male   M  ...          unknown
# 6298                  Ahmun   M  ...          unknown
# 6299  Coast Guard personnel   M  ...          unknown
# 6300        Jules Patterson   M  ...          unknown
# 6301                   male   M  ...          unknown
#
#                      investigator_or_source                             pdf  \
# 0                          R. Collier, GSAF            2018.06.25-Wolfe.pdf
# 1            K.McMurray, TrackingSharks.com          2018.06.18-McNeely.pdf
# 2            K.McMurray, TrackingSharks.com           2018.06.09-Denges.pdf
# 3                            B. Myatt, GSAF        2018.06.08-Arrawarra.pdf
# 4                                 A .Kipper            2018.06.04-Ramos.pdf
# ...                                     ...                             ...
# 6297       H. Taunton; N. Bartlett,  p. 234          ND-0005-RoebuckBay.pdf
# 6298  H. Taunton; N. Bartlett,  pp. 233-234               ND-0004-Ahmun.pdf
# 6299   F. Schwartz, p.23; C. Creswell, GSAF  ND-0003-Ocracoke_1900-1905.pdf
# 6300                    The Sun, 10/20/1938      ND-0002-JulesPatterson.pdf
# 6301                             S.W. Baker              ND-0001-Ceylon.pdf
#
#                                            href_formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href case_number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      case_number.2 original_order unnamed:_22 unnamed:_23
# 0       2018.06.25         6303.0         NaN         NaN
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 3       2018.06.08         6300.0         NaN         NaN
# 4       2018.06.04         6299.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6297       ND.0005            6.0         NaN         NaN
# 6298       ND.0004            5.0         NaN         NaN
# 6299       ND.0003            4.0         NaN         NaN
# 6300       ND.0002            3.0         NaN         NaN
# 6301       ND.0001            2.0         NaN         NaN
#
# [6302 rows x 24 columns]

# %% [markdown]
# ### Limpiando un poco los años

# %%
tiburones[["year", "date", "case_number"]][tiburones["year"].isna()]
tiburones[["year", "date", "case_number"]][tiburones['year']<1500] #hay muchos años que directamente no tienen demasiado sentido, por ejemplo estos
# Out:
#        year            date case_number
# 6174  500.0  Circa 500 A.D.  0500.00.00
# 6175   77.0        77  A.D.  0077.00.00
# 6176    5.0      Ca. 5 A.D.  0005.00.00
# 6177    0.0    Ca. 214 B.C.   0000.0214
# 6178    0.0   Ca. 336.B.C..   0000.0336
# ...     ...             ...         ...
# 6297    0.0     Before 1903     ND.0005
# 6298    0.0     Before 1903     ND.0004
# 6299    0.0       1900-1905     ND.0003
# 6300    0.0       1883-1889     ND.0002
# 6301    0.0       1845-1853     ND.0001
#
# [128 rows x 3 columns]

# %%
#vamos a quitar lo anterior, demasiado general y poco fiable

tiburones.drop(index = tiburones[tiburones['year']<1500].index,inplace = True)
# Out:
#        case_number                      date    year        type  \
# 0       2018.06.25               25-Jun-2018  2018.0     Boating
# 1       2018.06.18               18-Jun-2018  2018.0  Unprovoked
# 2       2018.06.09               09-Jun-2018  2018.0     Invalid
# 3       2018.06.08               08-Jun-2018  2018.0  Unprovoked
# 4       2018.06.04               04-Jun-2018  2018.0    Provoked
# ...            ...                       ...     ...         ...
# 6169    1595.00.00                      1595  1595.0  Unprovoked
# 6170  1580.01.10.R  Letter dated 10-Jan-1580  1580.0  Unprovoked
# 6171    1555.00.00                      1555  1555.0  Unprovoked
# 6172    1554.00.00                  Ca. 1554  1554.0  Unprovoked
# 6173    1543.00.00                  Ca. 1543  1543.0  Unprovoked
#
#                        country                         area  \
# 0                          USA                   California
# 1                          USA                      Georgia
# 2                          USA                       Hawaii
# 3                    AUSTRALIA              New South Wales
# 4                       MEXICO                       Colima
# ...                        ...                          ...
# 6169                     INDIA                       Kerala
# 6170  Between PORTUGAL & INDIA                          NaN
# 6171                       NaN                          NaN
# 6172                    FRANCE            Nice & Marseilles
# 6173                 VENEZUELA  Magarita or Cubagua Islands
#
#                             location  \
# 0        Oceanside, San Diego County
# 1     St. Simon Island, Glynn County
# 2                       Habush, Oahu
# 3                 Arrawarra Headland
# 4                           La Ticla
# ...                              ...
# 6169                    River Cochin
# 6170                             NaN
# 6171                             NaN
# 6172                             NaN
# 6173                             NaN
#
#                                                activity  \
# 0                                              Paddling
# 1                                              Standing
# 2                                               Surfing
# 3                                               Surfing
# 4                                           Free diving
# ...                                                 ...
# 6169  Ship lay at anchor & man was working on its ru...
# 6170  Man fell overboard from ship. Those on board t...
# 6171                                           Swimming
# 6172                                                NaN
# 6173                                       Pearl diving
#
#                        name sex  ...          species  \
# 0               Julie Wolfe   F  ...      White shark
# 1            AdysonMcNeely    F  ...          unknown
# 2               John Denges   M  ...          unknown
# 3                      male   M  ...        2 m shark
# 4            Gustavo Ramos    M  ...  Tiger shark, 3m
# ...                     ...  ..  ...              ...
# 6169                   male   M  ...          unknown
# 6170                   male   M  ...          unknown
# 6171                   male   M  ...          unknown
# 6172  males (wearing armor)   M  ...      white_shark
# 6173           Indian slave   M  ...          unknown
#
#                          investigator_or_source  \
# 0                              R. Collier, GSAF
# 1                K.McMurray, TrackingSharks.com
# 2                K.McMurray, TrackingSharks.com
# 3                                B. Myatt, GSAF
# 4                                     A .Kipper
# ...                                         ...
# 6169  The Voyage of John Huyghen van Linschoten
# 6170                        G.P. Whitley, p. 10
# 6171                               Olaus Magnus
# 6172                               G. Rondelet
# 6173                                  J. Castro
#
#                                   pdf  \
# 0                2018.06.25-Wolfe.pdf
# 1              2018.06.18-McNeely.pdf
# 2               2018.06.09-Denges.pdf
# 3            2018.06.08-Arrawarra.pdf
# 4                2018.06.04-Ramos.pdf
# ...                               ...
# 6169            1595.00.00-Cochin.pdf
# 6170  1580.01.10.R-Portugal-India.pdf
# 6171    1555.00.00 - Olaus Magnus.pdf
# 6172          1554.00.00-Rondelet.pdf
# 6173        1543.00.00.R-LasCasas.pdf
#
#                                            href_formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6169  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6170  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6171  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6172  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6173  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href case_number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6169  http://sharkattackfile.net/spreadsheets/pdf_di...    1595.00.00
# 6170  http://sharkattackfile.net/spreadsheets/pdf_di...  1580.01.10.R
# 6171  http://sharkattackfile.net/spreadsheets/pdf_di...    1555.00.00
# 6172  http://sharkattackfile.net/spreadsheets/pdf_di...    1554.00.00
# 6173  http://sharkattackfile.net/spreadsheets/pdf_di...    1543.00.00
#
#      case_number.2 original_order unnamed:_22 unnamed:_23
# 0       2018.06.25         6303.0         NaN         NaN
# 1       2018.06.18         6302.0         NaN         NaN
# 2       2018.06.09         6301.0         NaN         NaN
# 3       2018.06.08         6300.0         NaN         NaN
# 4       2018.06.04         6299.0         NaN         NaN
# ...            ...            ...         ...         ...
# 6169    1595.00.00          134.0         NaN         NaN
# 6170  1580.01.10.R          133.0         NaN         NaN
# 6171    1555.00.00          132.0         NaN         NaN
# 6172    1554.00.00          131.0         NaN         NaN
# 6173    1543.00.00          130.0         NaN         NaN
#
# [6174 rows x 24 columns]
